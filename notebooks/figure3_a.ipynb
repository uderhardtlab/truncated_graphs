# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
from scipy.stats import pearsonr, vonmises_fisher
import seaborn as sns
import sys
import glob
from tqdm import trange 
sys.path.append("../src")
from sphere import *
sys.path.append("../../bosperrus-package/")

# %%
n = 5000
coords = sample_von_mises_fisher(n=n, kappas=[1, 3, 5])
crop, distances = crop_cap(coords, 1)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(coords[:,0], coords[:,1], coords[:,2], s=1, color="gray")
ax.scatter(coords[crop,0], coords[crop,1], coords[crop,2], s=1, c=distances)
plt.axis("square")
plt.axis("off")

plt.savefig("../result_plots/sphere.svg", bbox_inches="tight")
